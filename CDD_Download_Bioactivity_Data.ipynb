# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavalya-Periyasamy05/Machine-Learning-and-AI/blob/main/CDD_Download_Bioactivity_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery: Download Bioactivity Data **

# %% [markdown]
# # **ChEMBL Database**

# %% [markdown]
# ## Installing libraries

# %%
! pip install chembl_webresource_client # This library will allow to download the biological activity data directly from the chembl database
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.12/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.11.12)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)

# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ## **Target search for cancer**
#
# ### KRAS (Kirsten Rat Sarcoma Viral Oncogene Homolog) is a small GTPase protein that acts as a molecular switch in cell signaling, controlling cell growth, differentiation, and survival. Mutations in KRAS, such as G12C, are linked to cancers, making it a key target for drug bioactivity studies.

# %%
#target = new_client.target
target_query = new_client.target.search("KRAS")
targets = pd.DataFrame.from_dict(target_query) # from_dic tells the  pandas that data isin dictionary format
targets
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
# 5               []  Homo sapiens
# 6               []  Homo sapiens
#
#                                          pref_name  score  species_group_flag  \
# 0                                      GTPase KRas   19.0               False
# 1                            Protein cereblon-KRAS   19.0               False
# 2  von Hippel-Lindau disease tumor suppressor/KRAS   18.0               False
# 3                                        SOS1-KRAS   18.0               False
# 4                                       PDE6D/KRAS   17.0               False
# 5                                 GTPase KRas/RAF1   17.0               False
# 6                                              RAS   15.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL2189121  [{'accession': 'P01116', 'component_descriptio...
# 1    CHEMBL5483196  [{'accession': 'P01116', 'component_descriptio...
# 2    CHEMBL5169273  [{'accession': 'P01116', 'component_descriptio...
# 3    CHEMBL5465393  [{'accession': 'Q07889', 'component_descriptio...
# 4    CHEMBL4523623  [{'accession': 'O43924', 'component_descriptio...
# 5    CHEMBL5291977  [{'accession': 'P04049', 'component_descriptio...
# 6    CHEMBL4524006  [{'accession': 'P01112', 'component_descriptio...
#
#                    target_type  tax_id
# 0               SINGLE PROTEIN    9606
# 1  PROTEIN-PROTEIN INTERACTION    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3              PROTEIN COMPLEX    9606
# 4  PROTEIN-PROTEIN INTERACTION    9606
# 5  PROTEIN-PROTEIN INTERACTION    9606
# 6               PROTEIN FAMILY    9606

# %% [markdown]
# ### Single protein target for further investigation

# %% [markdown]
# ## Retrieve bioactivity data for the cancer-associated GTPase KRAS (first entry)

# %%
selected_target = targets.target_chembl_id[0] # assign first entry to the selected_target variable
selected_target
# Out:
# 'CHEMBL2189121'

# %% [markdown]
# ## Filter compounds reported as IC50 values in nM

# %%
res = new_client.activity.filter(target_chembl_id = selected_target).filter(standard_type ="IC50") # IC50 standard type filter is to make the data uniform by excluding EC50 and percent activity std types.

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     13352855                  []
# 1        None             None     13352856                  []
# 2        None             None     14548911                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2399318  Inhibition of full-length human KRas4B (amino ...
# 1   CHEMBL2399319  Inhibition of full-length human KRas4B (amino ...
# 2   CHEMBL3223233  Inhibition of recombinant HA-tagged K-Ras G12V...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                  P01116                   G12V  BAO_0000190  ...
#
#   target_organism target_pref_name target_tax_id text_value  toid  type units  \
# 0    Homo sapiens      GTPase KRas          9606       None  None  IC50    uM
# 1    Homo sapiens      GTPase KRas          9606       None  None  IC50    uM
# 2    Homo sapiens      GTPase KRas          9606       None  None  IC50    uM
#
#      uo_units upper_value  value
# 0  UO_0000065        None  155.0
# 1  UO_0000065        None  342.0
# 2  UO_0000065        None    1.2
#
# [3 rows x 46 columns]

# %%
# Sanity check to see whether the index needs to be reset.
print(len(df))
df.index.min(), df.index.max()
# Out:
# 5760
# (0, 5759)

# %%
# Sanity check if the data has not onlt IC50 std type
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# ### Saving the bioactivity data to a  csv format named **bioactivity_data.csv**

# %%
df.to_csv("bioactivity_data.csv", index=False) # False prevents the default Python (pandas) index from being added to the data.

# %% [markdown]
# ## Copying file to Google Drive

# %%
# Mount Drive
from google.colab import drive
drive.mount("/content/drive", force_remount=True) #Here, force_remount unmounts the Drive if it’s already connected and then remounts it, ensuring any recent changes in Drive are refreshed and accessible.
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Shell-based commands

# %%
# Creating Data folder in Colab Notebooks on google drive
! mkdir "/content/drive/My Drive/Colab Notebooks/Data" #Exclamation mark is required for running shell-based commands
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/Colab Notebooks/Data’: File exists

# %%
# Sanity check
! ls  # list the contents of the current opened folder.
! ls "/content/drive/My Drive/Colab Notebooks/"
! ls -l "/content/drive/My Drive/Colab Notebooks/" # dash l shows the time and data at which it is created
# Out:
# bioactivity_data.csv  drive  sample_data
#  CDD_Download_Bioactivity_Data.ipynb	       'ML_Classification (1).ipynb'
# 'Copy of CDD_Download_Bioactivity_Data.ipynb'   ML_Classification.ipynb
#  Data					        Untitled0.ipynb
#  Exploratory_Data_Analysis.ipynb	        Untitled1.ipynb
#  First_Project.ipynb			        Untitled2.ipynb
# total 510
# -rw------- 1 root root  25977 Dec 27 07:27  CDD_Download_Bioactivity_Data.ipynb
# -rw------- 1 root root 110478 Dec 29 13:21 'Copy of CDD_Download_Bioactivity_Data.ipynb'
# drwx------ 2 root root   4096 Dec 30 17:50  Data
# -rw------- 1 root root   9938 Dec 30 06:27  Exploratory_Data_Analysis.ipynb
# -rw------- 1 root root 268271 Dec 25 12:41  First_Project.ipynb
# -rw------- 1 root root   1005 Dec 25 18:05 'ML_Classification (1).ipynb'
# -rw------- 1 root root  85254 Dec 26 03:47  ML_Classification.ipynb
# -rw------- 1 root root    773 May 26  2021  Untitled0.ipynb
# -rw------- 1 root root   3231 May 26  2021  Untitled1.ipynb
# -rw------- 1 root root  10881 Nov 11  2024  Untitled2.ipynb

# %%
# Copying Data to Drive
! cp bioactivity_data.csv "/content/drive/My Drive/Colab Notebooks/Data"

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,13352855,[],CHEMBL2399318,Inhibition of full-length human KRas4B (amino acids 1 to 188)-SOS interaction assessed as inhibition of SOS-mediated nucleotide release activity,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL2396593,J Med Chem,2013,,CHEMBL2396992,,CHEMBL2396992,,0,http://www.openphacts.org/units/Nanomolar,1902314,=,1,1,=,,IC50,nM,,155000.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,155.0
# ,,13352856,[],CHEMBL2399319,Inhibition of full-length human KRas4B (amino acids 1 to 188)-SOS interaction assessed as inhibition of nucleotide exchange activity,B,,,BAO_0000190,BAO_0000357,single protein format,Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN,Outside typical range,"Values for this activity type are unusually large/small, so may not be accurate",CHEMBL2396593,J Med Chem,2013,,CHEMBL2396992,,CHEMBL2396992,,0,http://www.openphacts.org/units/Nanomolar,1902314,=,1,1,=,,IC50,nM,,342000.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,342.0
# ,,14548911,[],CHEMBL3223233,Inhibition of recombinant HA-tagged K-Ras G12V mutant (unknown origin) assessed as disruption of interaction with GST-tagged Raf-RBD after overnight incubation by HTRF assay,B,P01116,G12V,BAO_0000190,BAO_0000019,assay format,CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H](Cc2ccc(F)cc2)NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C@H](CCC(N)=O)NC(=O)C[C@@H](CCc2ccccc2)NC(=O)[C@@H]2CCCCN2C(=O)C(=O)C(C)(C)COC1=O,,,CHEMBL3217533,Medchemcomm,2013,"{'bei': '4.24', 'le': None, 'lle': None, 'sei': None}",CHEMBL3218635,,CHEMBL3218635,5.92,0,http://www.openphacts.org/units/Nanomolar,2073173,=,1,1,=,,IC50,nM,,1200.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,1.2
# ,,14548912,[],CHEMBL3223233,Inhibition of recombinant HA-tagged K-Ras G12V mutant (unknown origin) assessed as disruption of interaction with GST-tagged Raf-RBD after overnight incubation by HTRF assay,B,P01116,G12V,BAO_0000190,BAO_0000019,assay format,CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[C@@H](CCCCN)NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H](Cc2ccc(F)cc2)NC(=O)[C@H](CCC(N)=O)NC(=O)C[C@@H](CCc2ccccc2)NC(=O)[C@@H]2CCCCN2C(=O)C(=O)C(C)(C)COC1=O,,,CHEMBL3217533,Medchemcomm,2013,"{'bei': '3.33', 'le': None, 'lle': None, 'sei': None}",CHEMBL3218636,,CHEMBL3218636,5.00,0,http://www.openphacts.org/units/Nanomolar,2073174,=,1,1,=,,IC50,nM,,10000.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,10.0
# ,,14548913,[],CHEMBL3223233,Inhibition of recombinant HA-tagged K-Ras G12V mutant (unknown origin) assessed as disruption of interaction with GST-tagged Raf-RBD after overnight incubation by HTRF assay,B,P01116,G12V,BAO_0000190,BAO_0000019,assay format,CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC(=N)N)NC(=O)CNC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[C@H](CCCN)NC(=O)[C@H](CCC(N)=O)NC(=O)C[C@@H](CCc2ccccc2)NC(=O)[C@@H]2CCCCN2C(=O)C1=O,,,CHEMBL3217533,Medchemcomm,2013,"{'bei': '4.17', 'le': None, 'lle': None, 'sei': None}",CHEMBL3218637,,CHEMBL3218637,5.75,0,http://www.openphacts.org/units/Nanomolar,2073175,=,1,1,=,,IC50,nM,,1800.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,1.8
# ,,14548914,[],CHEMBL3223233,Inhibition of recombinant HA-tagged K-Ras G12V mutant (unknown origin) assessed as disruption of interaction with GST-tagged Raf-RBD after overnight incubation by HTRF assay,B,P01116,G12V,BAO_0000190,BAO_0000019,assay format,CC(C)C[C@@H]1NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C@H](Cc2ccc(F)cc2)NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H](CCC(N)=O)NC(=O)C[C@@H](CCc2ccccc2)NC(=O)[C@@H]2CCCCN2C(=O)C(=O)C(C)(C)COC1=O,,,CHEMBL3217533,Medchemcomm,2013,"{'bei': '4.61', 'le': None, 'lle': None, 'sei': None}",CHEMBL3218638,,CHEMBL3218638,6.70,0,http://www.openphacts.org/units/Nanomolar,2073176,=,1,1,=,,IC50,nM,,200.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,0.2
# ,,14548915,[],CHEMBL3223233,Inhibition of recombinant HA-tagged K-Ras G12V mutant (unknown origin) assessed as disruption of interaction with GST-tagged Raf-RBD after overnight incubation by HTRF assay,B,P01116,G12V,BAO_0000190,BAO_0000019,assay format,CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC(=N)N)NC(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C@@H]2CCCN2C(=O)[C@H](Cc2ccc(O)cc2)NC(=O)[C@@H](Cc2ccccc2)NC(=O)[C@H](CCC(N)=O)NC(=O)C[C@@H](CCc2ccccc2)NC(=O)[C@@H]2CCCCN2C(=O)C1=O,,,CHEMBL3217533,Medchemcomm,2013,"{'bei': '3.53', 'le': None, 'lle': None, 'sei': None}",CHEMBL3218639,,CHEMBL3218639,5.00,0,http://www.openphacts.org/units/Nanomolar,2073177,=,1,1,=,,IC50,nM,,10000.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,10.0
# ,,14548916,[],CHEMBL3223233,Inhibition of recombinant HA-tagged K-Ras G12V mutant (unknown origin) assessed as disruption of interaction with GST-tagged Raf-RBD after overnight incubation by HTRF assay,B,P01116,G12V,BAO_0000190,BAO_0000019,assay format,CC(C)C[C@@H]1NC(=O)[C@H](CCC(=O)O)NC(=O)[C@H](c2ccccc2)NC(=O)[C@@H](Cc2ccccc2)NC(=O)[C@H](CCCN)NC(=O)[C@@H]2CCCN2C(=O)[C@H](CCC(N)=O)NC(=O)C[C@@H](CCc2ccccc2)NC(=O)[C@@H]2CCCCN2C(=O)C(=O)C(C)(C)COC1=O,,,CHEMBL3217533,Medchemcomm,2013,"{'bei': '3.92', 'le': None, 'lle': None, 'sei': None}",CHEMBL3218640,,CHEMBL3218640,5.00,0,http://www.openphacts.org/units/Nanomolar,2073178,=,1,1,=,,IC50,nM,,10000.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,10.0
# ,,14548917,[],CHEMBL3223233,Inhibition of recombinant HA-tagged K-Ras G12V mutant (unknown origin) assessed as disruption of interaction with GST-tagged Raf-RBD after overnight incubation by HTRF assay,B,P01116,G12V,BAO_0000190,BAO_0000019,assay format,CCCC[C@H]1NC(=O)[C@H](Cc2ccc(F)cc2)NC(=O)[C@H](CCCN=C(N)N)NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[C@H](CCCN=C(N)N)NC(=O)[C@H](CCCN=C(N)N)NC(=O)[C@H](CCC(N)=O)NC(=O)C[C@@H](CCc2ccccc2)NC(=O)[C@@H]2CCCCN2C(=O)C(=O)C(C)(C)COC1=O,,,CHEMBL3217533,Medchemcomm,2013,"{'bei': '4.14', 'le': None, 'lle': None, 'sei': None}",CHEMBL3218641,,CHEMBL3218641,6.16,0,http://www.openphacts.org/units/Nanomolar,2073179,=,1,1,=,,IC50,nM,,700.0,CHEMBL2189121,Homo sapiens,GTPase KRas,9606,,,IC50,uM,UO_0000065,,0.7

# %% [markdown]
# ## **Handling missing data**

# %% [markdown]
# ### Drop any compounds that has missing value for the standard value column

# %%
print(df["standard_value"].isna().sum()) # gives the count for column "standard_type"
print(df["standard_value"].isna().any()) # Boolean: True if column "standard_value" has NaN
# Out:
# 22
# True

# %%
df2 = df[df.standard_value.notna()] # gives filtered dataframe
df2
print(len(df2))
df2.index.min(), df2.index.max()
# Out:
# 5738
# (np.int64(0), np.int64(5759))

# %%
# sanity check fot a specific column
print(df2["standard_value"].isna().sum()) # gives the count for column "standard_type"
print(df2["standard_value"].isna().any()) # Boolean: True if column "standard_value" has NaN

# sanity check across all columns
#print(df2.isna().any().any()) # Returns single true.isna() → marks NaN as True. First .any() → checks column-wise.Second .any() → checks across all columns.
#print(df2.isna().sum()) # gives count for all columns individually.

#Filter columns (prints columns which have NAN)
# print(df2.loc[:,df2.isna().any()]) # When filtering columns, .loc with : is required because df2[..] selects rows by default.

#Filter Rows (prints rows which have NAN)
#print(df2[df2.isna().any(axis=1)]) # rows that contain at least one NaN.
# Out:
# 0
# False

# %%
# Reset the index
df2 = df2.reset_index(drop=True)
# sanity check
print(len(df2))
df2.index.min(), df2.index.max()
# Out:
# 5738
# (0, 5737)

# %% [markdown]
# ## Drop any compounds that has missing values for canonical notation

# %%
# Sanity check
print(df2["canonical_smiles"].isna().sum()) # gives the count for column "canonical_smiles"
print(df2["canonical_smiles"].isna().any()) # Boolean: True if column "canonical_smiles"  has NaN
# Out:
# 8
# True

# %%
# Filter
df2 = df2[df2.canonical_smiles.notna()] # gives filtered dataframe
df2
print(len(df2))
df2.index.min(), df2.index.max()
# Out:
# 5730
# (np.int64(0), np.int64(5737))

# %%
# Reset the index
df2 = df2.reset_index(drop=True)
# sanity check
print(len(df2))
df2.index.min(), df2.index.max()
# Out:
# 5730
# (0, 5729)

# %%
# Sanity check
print(df2["canonical_smiles"].isna().sum()) # gives the count for column "canonical_smiles"
print(df2["canonical_smiles"].isna().any()) # Boolean: True if column "canonical_smiles" has NaN
# Out:
# 0
# False

# %% [markdown]
# ## **Drop any compounds that has missing values for chembl id **

# %%
# sanity check
print(df2["molecule_chembl_id"].isna().any())
print(df2["molecule_chembl_id"].isna().sum())
# Out:
# False
# 0

# %%
# Filter
# notna(): isna() can miss missing values when they appear in string/object columns, as missing entries may not always be stored as numeric NaNs. notna() reliably filters out all missing values regardless of data type.
df2 = df2[df2.molecule_chembl_id.notna()] # gives filtered dataframe
df2
print(len(df2))
df2.index.min(), df2.index.max()
# Out:
# 5730
# (0, 5729)

# %% [markdown]
# ## Data pre-processing of the bioactivity data

# %% [markdown]
# ### Labeling compounds as either being active, inactive or intermediate

# %% [markdown]
# ### The bioactivity data is in IC50 unit. Compounds having values of less than 1000nM will be considered to be **active** while those greater than 10,000 will be considered to be **inactive**. As for those values in between 1000 and 10,000 nM will be referred to be as **intermediate**. (1 micromolar = 1000 nanomolar (nM) )

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
len(bioactivity_class) #total items in a list
# Out:
# 5730

# %% [markdown]
# ## DataFrame curation using key X features (molecule_chembl_id, canonical_smiles, and standard_value) and the Y feature (bioactivity_class).

# %% [markdown]
# ## Iterate the molecule_chembl_id to a list

# %%
mol_cid =[]
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ## Iterate canonical_smiles to a list

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ## Iterate standrad_value to a list

# %%
standard_value = []
for i in df.standard_value:
  standard_value.append(i)

# %% [markdown]
# ## Tuples were used to efficiently collect and align elements from all the generated lists.

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value)) # Zip, creates tuples row-wise. list, collects all tuples into a list.
df3 = pd.DataFrame(data_tuples, columns =["molecule_chembl_id", "canonical_smiles", "bioactivity_data", "standard_value"])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 1         CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 2         CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 3         CHEMBL3218636  CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...
# 4         CHEMBL3218637  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# ...                 ...                                                ...
# 5725      CHEMBL5768373  C=CC(=O)N1CC2(CC(n3nc(-c4cccc(=O)n4C)c(-c4c(Cl...
# 5726      CHEMBL5768373  C=CC(=O)N1CC2(CC(n3nc(-c4cccc(=O)n4C)c(-c4c(Cl...
# 5727      CHEMBL6000934  C=CC(=O)N1CC2(CC(n3nc(-c4cc(C)nn4CCN(C)C)c(-c4...
# 5728      CHEMBL6000934  C=CC(=O)N1CC2(CC(n3nc(-c4cc(C)nn4CCN(C)C)c(-c4...
# 5729      CHEMBL5809308  C=CC(=O)N1CC2(CC(n3nc(-c4ccc5c(cnn5C)c4)c(-c4c...
#
#      bioactivity_data standard_value
# 0            inactive       155000.0
# 1            inactive       342000.0
# 2        intermediate         1200.0
# 3            inactive        10000.0
# 4        intermediate         1800.0
# ...               ...            ...
# 5725     intermediate          536.0
# 5726         inactive        50000.0
# 5727     intermediate          335.0
# 5728         inactive        21600.0
# 5729     intermediate         1300.0
#
# [5730 rows x 4 columns]

# %% [markdown]
# ## Alternative method

# %%
selection = ["molecule_chembl_id", "canonical_smiles", "standard_value"]
df3 = df2[selection]
df3
print(df3.index[:10])
print(pd.Series(bioactivity_class).index[:10])
print(df3.index.is_unique)
print(df3.index.min(), df3.index.max())
# Out:
# RangeIndex(start=0, stop=10, step=1)
# RangeIndex(start=0, stop=10, step=1)
# True
# 0 5729

# %%
# Rename the class column from 0 to bioactivity_class

df3 = pd.concat([df3, pd.Series(bioactivity_class, name ="bioactivity_class")], axis=1)
df3

# or

#df3 = pd.concat([df3, pd.Series(bioactivity_class)], axis=1) # pd.Series: concat expects in series or DataFrame format
#df3.rename(columns ={0:"bioactivity_class"})
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 1         CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 2         CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 3         CHEMBL3218636  CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...
# 4         CHEMBL3218637  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# ...                 ...                                                ...
# 5725      CHEMBL5768373  C=CC(=O)N1CC2(CC(n3nc(-c4cccc(=O)n4C)c(-c4c(Cl...
# 5726      CHEMBL5768373  C=CC(=O)N1CC2(CC(n3nc(-c4cccc(=O)n4C)c(-c4c(Cl...
# 5727      CHEMBL6000934  C=CC(=O)N1CC2(CC(n3nc(-c4cc(C)nn4CCN(C)C)c(-c4...
# 5728      CHEMBL6000934  C=CC(=O)N1CC2(CC(n3nc(-c4cc(C)nn4CCN(C)C)c(-c4...
# 5729      CHEMBL5809308  C=CC(=O)N1CC2(CC(n3nc(-c4ccc5c(cnn5C)c4)c(-c4c...
#
#      standard_value bioactivity_class
# 0          155000.0          inactive
# 1          342000.0          inactive
# 2            1200.0      intermediate
# 3           10000.0          inactive
# 4            1800.0      intermediate
# ...             ...               ...
# 5725         5300.0      intermediate
# 5726        25300.0          inactive
# 5727         1400.0      intermediate
# 5728        43000.0          inactive
# 5729         2300.0      intermediate
#
# [5730 rows x 4 columns]

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 1         CHEMBL2396992                       Cc1[nH]c2cc(Cl)cc(Cl)c2c1CCN
# 2         CHEMBL3218635  CC(C)[C@@H]1NC(=O)[C@@H](CC(N)=O)NC(=O)[C@H](C...
# 3         CHEMBL3218636  CCCC[C@H]1NC(=O)[C@@H](Cc2ccc3ccccc3c2)NC(=O)[...
# 4         CHEMBL3218637  CC1(C)COC(=O)[C@H](Cc2ccccc2)NC(=O)[C@H](CCCNC...
# ...                 ...                                                ...
# 5725      CHEMBL5768373  C=CC(=O)N1CC2(CC(n3nc(-c4cccc(=O)n4C)c(-c4c(Cl...
# 5726      CHEMBL5768373  C=CC(=O)N1CC2(CC(n3nc(-c4cccc(=O)n4C)c(-c4c(Cl...
# 5727      CHEMBL6000934  C=CC(=O)N1CC2(CC(n3nc(-c4cc(C)nn4CCN(C)C)c(-c4...
# 5728      CHEMBL6000934  C=CC(=O)N1CC2(CC(n3nc(-c4cc(C)nn4CCN(C)C)c(-c4...
# 5729      CHEMBL5809308  C=CC(=O)N1CC2(CC(n3nc(-c4ccc5c(cnn5C)c4)c(-c4c...
#
#      standard_value bioactivity_class
# 0          155000.0          inactive
# 1          342000.0          inactive
# 2            1200.0      intermediate
# 3           10000.0          inactive
# 4            1800.0      intermediate
# ...             ...               ...
# 5725         5300.0      intermediate
# 5726        25300.0          inactive
# 5727         1400.0      intermediate
# 5728        43000.0          inactive
# 5729         2300.0      intermediate
#
# [5730 rows x 4 columns]

# %% [markdown]
# ## Sanity check: Duplicated chembl ID

# %%
df3['molecule_chembl_id'].duplicated().any() # Check if there are any duplicate ChEMBL IDs at all
# Out:
# np.True_

# %%
df3['molecule_chembl_id'].duplicated().sum() # See how many duplicate entries (extra occurrences) exist, excluding the first occurrence.
# Out:
# np.int64(2979)

# %%
df3['molecule_chembl_id'][df3['molecule_chembl_id'].duplicated()].nunique() #How many unique (first-occurrence) ChEMBL IDs appear more than once in the dataset
# Out:
# 1708

# %%
df3_unique = df3.drop_duplicates(subset=['molecule_chembl_id'], keep='first') # remove all extra occurrences but keep the first occurrence of each ChEMBL ID.

# %%
# sanity check
df3_unique['molecule_chembl_id'].duplicated().any()
# Out:
# np.False_

# %%
# sanity check
print(df3_unique.index.min(), df3_unique.index.max())
print(len(df3_unique))

# Rest index
# Out:
# 0 5716
# 2751

# %%
df4 = df3_unique.reset_index(drop=True)
# or

#df3_unique.reset_index(drop=True, inplace= True) # No need to create a new variable df4
#sanity check
print(df4.index.min(), df4.index.max())
print(len(df4))
# Out:
# 0 2750
# 2751

# %% [markdown]
# ## Save dataframe to CSV file

# %%
df4.to_csv("bioactivity_preprocessed_data.csv", index=False)

# %%
! ls -l
# Out:
# total 8796
# -rw-r--r-- 1 root root 8618041 Dec 30 18:14 bioactivity_data.csv
# -rw-r--r-- 1 root root  374626 Dec 30 18:23 bioactivity_preprocessed_data.csv
# drwx------ 6 root root    4096 Dec 30 18:14 drive
# drwxr-xr-x 1 root root    4096 Dec 11 14:34 sample_data

# %% [markdown]
# ## Copy the bioactivity preprocessed data dataframe to Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/drive/My Drive/Colab Notebooks/Data"

# %%
! ls -l "/content/drive/My Drive/Colab Notebooks/Data"
# Out:
# total 8783
# -rw------- 1 root root 8618041 Dec 30 18:15 bioactivity_data.csv
# -rw------- 1 root root  374626 Dec 30 18:23 bioactivity_preprocessed_data.csv

# %% [markdown]
# ###
